# %% [markdown]
# #  Northwind Traders: E-Commerce Exploratory Data Analysis (EDA)
# **Author:** Shekh Shahed Jiban
# **GitHub:** [GitHub Profile](https://github.com/shekhshahedjiban-crypto)
# **LinkedIn:** [LinkedIn Profile](https://www.linkedin.com/in/shekh-shahed-jiban-5667a8296)
# **Email:** shekhshahedjiban@gmail.com
#
# ##  Project Overview
# This project performs an in depth Exploratory Data Analysis (EDA) on the classic **Northwind Traders** relational database using Python, SQL, and Data Visualization libraries. The objective is to extract meaningful business insights regarding top selling products, customer purchasing behavior, and revenue trends.
#
# ##  Tools & Libraries Used
# - **Python & SQL** (Core data extraction)
# - **Pandas & NumPy** (Data manipulation)
# - **Matplotlib & Seaborn** (Data visualization)
# - **MySQL Connector** (Database connection)

# %% [markdown]
# ### Import Libraries & Database Connection
# Importing necessary Python libraries and establishing a secure connection to the local MySQL Northwind database.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mysql.connector

# %%
# setting visual styles
sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)
import warnings
warnings.filterwarnings('ignore')

# %%
# establishing connection to the local MySQL Northwind database
try:
    conn = mysql.connector.connect(
        host="localhost",
        user="root",
        password="73737",
        database="northwind"
    )
    print(" Successfully connected to Northwind MySQL Database!")
except Exception as e:
    print(f" Connection failed: {e}")
# Out:
#  Successfully connected to Northwind MySQL Database!
